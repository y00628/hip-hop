# %%
import numpy as np
import pandas as pd

# %%
with open('genius_hip_hop_lyrics.csv', 'r', encoding='utf-8', errors='ignore') as file:
    content = file.read()

with open('genius_hip_hop_lyrics_cleaned.csv', 'w', encoding='utf-8') as file:
    file.write(content)

hip_hop = pd.read_csv('genius_hip_hop_lyrics_cleaned.csv')

hip_hop = hip_hop.set_index('id')

hip_hop
# Out:
#          candidate                     song              artist sentiment
# id
# 1    Mike Huckabee          None Shall Pass          Aesop Rock   neutral  \
# 2    Mike Huckabee                Wellstone           Soul Khan  negative
# 3         Jeb Bush                      Awe          Dez & Nobs   neutral
# 4         Jeb Bush                The Truth            Diabolic  negative
# 5         Jeb Bush                Money Man         Gorilla Zoe  negative
# ..             ...                      ...                 ...       ...
# 374   Donald Trump               On the Way          Young Thug  positive
# 375   Donald Trump                Digest It               Tiara  negative
# 376   Donald Trump        Constantly Hating          Young Thug  positive
# 377   Donald Trump  FDT (Fuck Donald Trump)  YG & Nipsey Hussle  negative
# 378   Donald Trump          It's Goin' Down            Yung Joc  positive
#
#          theme  album_release_date
# id
# 1          NaN                2011  \
# 2          NaN                2012
# 3          NaN                2006
# 4    political                2006
# 5     personal                2007
# ..         ...                 ...
# 374      money                2014
# 375  political                2016
# 376      money                2015
# 377  political                2016
# 378      money                2006
#
#                                                   line
# id
# 1    Wither by the watering hole, Border patrol / W...  \
# 2    Might find the door but never touch the key / ...
# 3           I heard Jeb Bush looking for a (inaudible)
# 4    What you heard before ain't as big of a lesson...
# 5    I'm comin back from Florida / Wit Jeb Bush and...
# ..                                                 ...
# 374  Bitches got bumps and I'm rich just like Donal...
# 375  The world gon' end real soon, especially if Tr...
# 376  I've seen more holes than a golf course on Don...
# 377                                  Fuck Donald Trump
# 378      Boys from the hood call me black Donald Trump
#
#                                                    url
# id
# 1    http://genius.com/Aesop-rock-none-shall-pass-l...
# 2         http://genius.com/Soul-khan-wellstone-lyrics
# 3            http://genius.com/Dez-and-nobs-awe-lyrics
# 4          http://genius.com/Diabolic-the-truth-lyrics
# 5       http://genius.com/Gorilla-zoe-money-man-lyrics
# ..                                                 ...
# 374       http://genius.com/Mpa-duke-on-the-way-lyrics
# 375     http://genius.com/Royce-da-59-digest-it-lyrics
# 376  http://genius.com/Young-thug-constantly-hating...
# 377  http://genius.com/Yg-and-nipsey-hu-le-fdt-fuck...
# 378    http://genius.com/Yung-joc-its-goin-down-lyrics
#
# [377 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sentiment Distribution
sns.countplot(x='sentiment', data=hip_hop)
plt.title('Sentiment Distribution')
plt.show()

# Distribution of Themes
sns.countplot(x='theme', data=hip_hop)
plt.title('Theme Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
hip_hop_subset = hip_hop[['artist', 'sentiment', 'line']]
hip_hop_subset
# Out:
#                  artist sentiment
# id
# 1            Aesop Rock   neutral  \
# 2             Soul Khan  negative
# 3            Dez & Nobs   neutral
# 4              Diabolic  negative
# 5           Gorilla Zoe  negative
# ..                  ...       ...
# 374          Young Thug  positive
# 375               Tiara  negative
# 376          Young Thug  positive
# 377  YG & Nipsey Hussle  negative
# 378            Yung Joc  positive
#
#                                                   line
# id
# 1    Wither by the watering hole, Border patrol / W...
# 2    Might find the door but never touch the key / ...
# 3           I heard Jeb Bush looking for a (inaudible)
# 4    What you heard before ain't as big of a lesson...
# 5    I'm comin back from Florida / Wit Jeb Bush and...
# ..                                                 ...
# 374  Bitches got bumps and I'm rich just like Donal...
# 375  The world gon' end real soon, especially if Tr...
# 376  I've seen more holes than a golf course on Don...
# 377                                  Fuck Donald Trump
# 378      Boys from the hood call me black Donald Trump
#
# [377 rows x 3 columns]

# %%
import nltk
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import nltk
#
# File c:\Python311\Lib\site-packages\nltk\__init__.py:115
#     108 ###########################################################
#     109 # TOP-LEVEL MODULES
#     110 ###########################################################
#     111
#     112 # Import top-level functionality into top-level namespace
#     114 from nltk.collocations import *
# --> 115 from nltk.decorators import decorator, memoize
#     116 from nltk.featstruct import *
#     117 from nltk.grammar import *
#
# File c:\Python311\Lib\site-packages\nltk\decorators.py:187
#     184         setattr(obj, name, default)
#     185         return default
# --> 187 @decorator
#     188 def memoize(func, *args):
#     189     dic = getattr_(func, "memoize_dic", dict)
#     190     # memoize_dic is created at the first call
#
# File c:\Python311\Lib\site-packages\nltk\decorators.py:176, in decorator(caller)
#     174     dec_func = eval(src, dict(_func_=func, _call_=caller))
#     175     return update_wrapper(dec_func, func, infodict)
# --> 176 return update_wrapper(_decorator, caller)
#
# File c:\Python311\Lib\site-packages\nltk\decorators.py:87, in update_wrapper(wrapper, model, infodict)
#      86 def update_wrapper(wrapper, model, infodict=None):
# ---> 87     infodict = infodict or getinfo(model)
#      88     wrapper.__name__ = infodict['name']
#      89     wrapper.__doc__ = infodict['doc']
#
# File c:\Python311\Lib\site-packages\nltk\decorators.py:69, in getinfo(func)
#      67 if varkwargs:
#      68     argnames.append(varkwargs)
# ---> 69 signature = inspect.formatargspec(regargs, varargs, varkwargs, defaults,
#      70                                   formatvalue=lambda value: "")[1:-1]
#      72 # pypy compatibility
#      73 if hasattr(func, '__closure__'):
#
# AttributeError: module 'inspect' has no attribute 'formatargspec'

# %%
#print(nltk.__version__)
print(sklearn.__version__)
print(imblearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #print(nltk.__version__)
# ----> 2 print(sklearn.__version__)
#       3 print(imblearn.__version__)
#
# NameError: name 'sklearn' is not defined
